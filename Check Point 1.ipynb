# %%
import pandas as pd
import numpy as np
import math as mt

# %%
#reading Datasets
JoiningStatus= JS = pd.read_csv (r'C:\Users\mohkt\Desktop\AI Academy\Project\Capstone4_HRData\Joining_Status.csv')
data = pd.read_csv (r'C:\Users\mohkt\Desktop\AI Academy\Project\Capstone4_HRData\HR_Hiring_details_transaction.csv')

# %%
#Checking for null values
JS.isnull().sum()
# Out:
# Candidate_Ref    0
# Status           0
# dtype: int64

# %%
#Taking Count
x =JS.Status.count()
y = JS['Status'].value_counts().Joined
print(x,y)
# Out:
# 8995 7313

# %%
#
#Percentage Joined
PercentJoined = y/x
PercentJoined
# Out:
# 0.8130072262367982

# %%
#Merging the datasets
df = pd.merge(JS,data)
df
# Out:
#       Candidate_Ref  Status    Sno DOJ_Extended  Duration_to_accept_offer  \
# 0           2110407  Joined      1          Yes                        14
# 1           2112635  Joined      2           No                        18
# 2           2112838  Joined      3           No                         3
# 3           2115021  Joined      4           No                        26
# 4           2115125  Joined      5          Yes                         1
# ...             ...     ...    ...          ...                       ...
# 8990        3822427  Joined  12319           No                         4
# 8991        3828206  Joined  12327          Yes                         2
# 8992        3834159  Joined  12331           No                         0
# 8993        3835433  Joined  12332           No                         0
# 8994        3836076  Joined  12333           No                         2
#
#       Notice_Period Offered_Band  Percent_hike_expected_in_CTC  \
# ...
